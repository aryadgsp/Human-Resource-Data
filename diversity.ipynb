# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('Diversity.txt', sep='\t')
df.head()
# Out:
#    EmployeeID  Gender Gender Identity      Race/Ethnicity  Veteran  \
# 0      100001  female          female               White        0
# 1      100002    male            male               White        0
# 2      100003  female          female               Asian        0
# 3      100004    male            male               White        0
# 4      100005    male            male  Hispanic or Latino        0
#
#    Disability      Education Sexual Orientation
# 0           0  Undergraduate       Heterosexual
# 1           1  Undergraduate       Heterosexual
# 2           0  Undergraduate       Heterosexual
# 3           0  Undergraduate       Heterosexual
# 4           0  Undergraduate            Missing

# %%
df.drop(['EmployeeID'], axis=1)
# Out:
#       Gender    Gender Identity      Race/Ethnicity  Veteran  Disability  \
# 0     female             female               White        0           0
# 1       male               male               White        0           1
# 2     female             female               Asian        0           0
# 3       male               male               White        0           0
# 4       male               male  Hispanic or Latino        0           0
# ...      ...                ...                 ...      ...         ...
# 4963    male               male               Asian        0           0
# 4964  female             female  Hispanic or Latino        0           0
# 4965    male               male               White        0           0
# 4966    male  Prefer not to say               White        0           0
# 4967  female             female               White        0           0
#
#           Education Sexual Orientation
# 0     Undergraduate       Heterosexual
# ...
